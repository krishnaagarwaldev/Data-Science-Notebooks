# %%
import numpy as np
import matplotlib.pyplot as plt

# set width of bar
barWidth = 0.25
# fig = plt.subplots(figsize =(12, 8))
# fig = plt.subplots()
# set height of bar
IT = [12, 30, 10, 8, 22]
ECE = [28, 6, 16, 5, 10]
CSE = [29, 3, 24, 25, 17]

# Set position of bar on X axis
br1 = np.arange(len(IT))
br2 = [x + barWidth for x in br1]
br3 = [x + barWidth for x in br2]

# Make the plot
plt.bar(br1, IT, color ='r', width = barWidth,
        edgecolor ='grey', label ='IT')
plt.bar(br2, ECE, color ='g', width = barWidth,
        edgecolor ='grey', label ='ECE')
plt.bar(br3, CSE, color ='b', width = barWidth,
        edgecolor ='grey', label ='CSE')

# Adding Xticks
plt.xlabel('Branch', fontweight ='bold', fontsize = 15)
plt.ylabel('Students passed', fontweight ='bold', fontsize = 15)
plt.xticks([r + barWidth for r in range(len(IT))], ['2015', '2016', '2017', '2018', '2019'])
plt.legend()
plt.show()

# %% [markdown]
# Pie Charts

# %%
import matplotlib.pyplot as plt
lab = ['Frogs', 'Hogs', 'Dogs', 'Logs']
sizes = [15, 30, 45, 10]
c=['green','olivedrab','rosybrown','maroon']
plt.pie(sizes,labels=lab,startangle=90,
        autopct='%1.1f%%',colors=c,explode=(.1,0,0,0),
        shadow=True,pctdistance=.5, labeldistance=1.1)
plt.legend(bbox_to_anchor = (3.27, 1))
plt.show()

# %% [markdown]
# Create piecharts to compare the marks distribution (% of students passed for Minor 1) on three subjects(Physics, Python and TDM) for AIDS branch

# %% [markdown]
# Simple scatter plots

# %%
year = '2018', '2019', '2020', '2021'
no_students_ECE = [35, 60, 45, 60]
# size=[100,200,300,400]
colors=["red","green","olivedrab","brown"]
plt.scatter(year, no_students_ECE, label=year, c=colors,s=size)

# %% [markdown]
# To compare two scatter plots

# %%
year = '2018', '2019', '2020', '2021'
l=["ECE","CSE"]
no_students_ECE = [35, 60, 45, 61]
size=[100,200,300,400]
colors=["red","green","olivedrab","brown"]
plt.scatter(year, no_students_ECE, label=l[0], c=colors,s=size)

no_students_CSE = [39, 63, 49, 60]
size=[100,200,300,400]
colors=["blue","rosybrown","green","red"]

#To change x and y axes values, use x and y ticks
plt.xticks([0,1,2,3], ["'18","'19","'20","'21"])
plt.scatter(year, no_students_CSE, label=l[1], c=colors,s=size)
plt.legend()
plt.show()

# %% [markdown]
# Box Plots

# %%
# Creating dataset
data_1 = [120, 60,30,45,49,90,95,99]
plt.boxplot(data_1)
plt.show()
# fig, ax = plt.subplots()
# ax = fig.add_axes([0,0,1,1]) #[left,bottom,width, height]
# plt.boxplot(data_1, patch_artist = False, vert = 1)

# %%
# Creating dataset
data = np.random.normal(100, 20, 200)
fig, ax = plt.subplots()
ax = fig.add_axes([0,0,1,1])
ax.boxplot(data, notch=True, patch_artist = True, vert = 1, boxprops=dict(facecolor='green'))
#Give X labels, Y labels and titles as appropriate
fig.show()

# %%
# Creating dataset
data = [125,70,35,45,52,95,99,1]
data_1 = [120, 60,30,45,49,90,95,99]
data_2=[data, data_1]
# fig = plt.figure()
plt.boxplot(data_2, patch_artist = True, notch=False, vert = 1)
#Give X labels, Y labels and titles as appropriate
plt.xticks([1,2],['2020','2022']) #To change x axis values
plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
x = [[1, 2, 3], [4, 5, 6]]
my_box_plots = plt.boxplot(x, patch_artist=True)
#Give X labels, Y labels and titles as appropriate
for box in my_box_plots["boxes"]:
    box.set(facecolor = "green")

# %% [markdown]
# To do now:

# %%
#Create boxplots to compare the marks distribution (of Minor 1) on three subjects(Physics, Python and TDM) of 12 students in AIDS branch

# %%
import matplotlib.pyplot as plt
labels = {'Physics':45, 'Python':55, 'TDM':60}
x=list(labels.keys())
y=list(labels.values())
# fig, ax = plt.subplots()
# ax.pie(sizes, labels=labels)
plt.pie(y,labels=labels,autopct='%.1f%%')
plt.legend(bbox_to_anchor = (1.27, 1))
plt.show()

# %%
import matplotlib.pyplot as plt
sub=['Physics','Python','TDM']
labels = {1:[45,55,60], 2:[55,57,62], 3:[60,60,69]}
x=list(labels.keys())
y=[]
for key,value in labels.items():
  y.append(list(value))
print(len(y[0]))
colors=['blue','red','green']
k=0
# fig, ax = plt.subplots()
# ax.pie(sizes, labels=labels)
for j,i in zip(x,y):
    for k in range(len(y[0])):
      plt.scatter(j,i[k],c=colors[k])
plt.legend(labels=sub)
plt.xticks([1,2,3],[1,2,3])
plt.title('Minor Marks Distribution')
#x label
#y label
plt.show()
# Out:
# 3

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
sub=["Phy","Py","TDM"]
x = [[1, 2, 3], [4, 5, 6], [7,8,9]]

my_box_plots = plt.boxplot(x, patch_artist=True)
# plt.xticks([1,2,3],sub)
plt.xticks(np.arange(1,len(sub)+1,1),sub)
plt.show()

# %%
import pandas as pd
data = pd.read_csv("/content/drive/MyDrive/TDM_Practice_data_files/cars.csv")
data

# %%
import csv

with open("titanic.csv", 'r') as file:
  csvreader = csv.reader(file)
  for row in csvreader:
    print(row)

# %%
import pandas as pd
data = pd.read_csv("titanic.csv")
data.head(5)

# %%
data.shape
# Out:
# (418, 12)

# %%
data.info()

# %%
data.describe()

# %%
data.nunique()

# %%
data['Age'].value_counts()

# %%
data['Sex'].value_counts()

# %%
data.columns

# %%
c=data['Sex'].value_counts()
c

# %%
plt.pie(data['Sex'].value_counts(),labels=['Male','Female'],autopct="%1.1f%%");

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).
# /gdrive

# %%
import os
os.chdir("/gdrive/MyDrive/TDM_Practice_data_files")
# !ls
# Out:
# cars.csv  titanic.csv

# %%
import pandas as pd
data = pd.read_csv("/gdrive/MyDrive/TDM_Practice_data_files/titanic.csv")
data.head(5)
