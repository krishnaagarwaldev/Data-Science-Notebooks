# %% [markdown]
# Bar plots

# %%
# Give values for X and Y
# X=[]
# Y =[]
# plot the bar plot using plt.bar(X,Y)

# %%
# import libraries#Creating Datasets
#Using Dictionaries
# data={"C":20, "C++":15}
data={1:1, 2:4}
#print all keys
print(data.keys())
k=list(data.keys())

# print(k[0],k[v.index(20)])
#Print all values from dictionary
v=list(data.values())

#Accessing single values
# print(data["C"])

#Create a dictionary of fruits and their prices(per kg) and print all fruit name whose price is greater than Rs. 200/Kg
fruit = {
    "banana": 1.00,
    "apple": 1.53,
    "kiwi": 2.00,
    "avocado": 3.23,
    "mango": 2.33,
    "pineapple": 1.44,
    "strawberries": 1.95,
    "melon": 2.34,
    "grapes": 0.98
}

for key,value in fruit.items():
    if value > 2.00:
         print(key)
# Out:
# dict_keys([1, 2])
# avocado
# mango
# melon

# %%
import numpy as np
import matplotlib.pyplot as plt

# creating the dataset
data = {'2017-21':20, '2018-22':15, '2019-23':30}
courses = list(data.keys())
values = list(data.values())

fig = plt.figure(figsize = (10, 5))

# creating the bar plot
plt.bar(courses, values, color ='maroon',
        width = 0.4)

plt.xlabel("Courses offered")
plt.ylabel("No. of students enrolled")
plt.title("Students enrolled in different courses")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
# year = (2018, 2019, 2020)
year = ('2018', '2019', '2020')
branch_counts = {
    'CS': np.array([73, 34, 61]),
    'AIDS': np.array([73, 34, 58]),
    "ECE":np.array([55, 56, 63]),
    "ME":np.array([72, 31, 68]),
}
# c=["red","green","blue","black"]
width=0.3
bottom=np.zeros(len(year))
for b, b_count in branch_counts.items():
    p = plt.bar(year, b_count, width, label=b, bottom=bottom)
    bottom += b_count
    plt.bar_label(p, label_type='center')
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
# year = (2018, 2019, 2020)
year = ('2017-21', '2018-22', '2019-23')
branch_counts = {
   ' Placement': np.array([27, 33, 32]),
    'Higher studies': np.array([2, 2, 0]),
    "Entrepreneurs":np.array([0, 0, 0])

}
width=0.25
c=["red","green","blue","black"]
plt.xlabel("Year")
plt.ylabel("No. of students")
plt.title("Improvement in Placement, Higher Studies and Entrepreneurship")

bottom=np.zeros(len(year))
for b, b_count in branch_counts.items():
    p = plt.bar(year, b_count, width, label=b, bottom=bottom)
    bottom += b_count
    plt.bar_label(p, label_type='center')
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
# year = (2018, 2019, 2020)
year = ('2018', '2019', '2020')
branch_counts = {
    'CS': np.array([73, 34, 61]),
    'AIDS': np.array([73, 34, 58]),
    "ECE":np.array([55, 56, 63]),
    "ME":np.array([72, 31, 68]),
}
# c=["red","green","blue","black"]
bottom=np.zeros(len(year))
for b, b_count in branch_counts.items():
    p = plt.barh(year, b_count, width, label=b, left=bottom)
    bottom += b_count
    plt.bar_label(p, label_type='center')
plt.legend()
plt.show()

# %% [markdown]
# # **Subplots (We have already discussed the concept of subplot in previous sessions; refer those)**
# # Here also the concepts are same.

# %%
species = ('Adelie', 'Chinstrap', 'Gentoo')
M_F_counts = {
    'Male': np.array([73, 34, 61]),
    'Female': np.array([73, 34, 58]),
}
width = 0.6  # the width of the bars: can also be len(x) sequence

fig, (ax1,ax2) = plt.subplots(2)

bottom = np.zeros(3)

for M_F, M_F_count in M_F_counts.items():
    p = ax1.bar(species, M_F_count, width, label=M_F, bottom=bottom)
    bottom += M_F_count

    ax1.bar_label(p, label_type='center')

ax1.set_title('Number of Male Female penguins')
ax1.set_xlabel("X axes")
#Y label
ax1.legend()

plt.show()

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
fruits = ['apple', 'blueberry', 'cherry', 'orange']
counts = [40, 100, 30, 55]
bar_labels = ['red', 'blue', '_red', 'orange']
bar_colors = ['red', 'blue', 'red', 'orange']
ax.bar(fruits, counts, label=bar_labels, color=bar_colors)
ax.set_ylabel('fruit supply')
ax.set_title('Fruit supply by kind and color')
ax.legend(title='Fruit color')
plt.show()

# %% [markdown]
# ## Modify the above code to obtain the following Output

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Try to understand the codes in the following two cells**

# %%
import numpy as np
import matplotlib.pyplot as plt

# year = ('2017-21', '2018-22', '2019-23')
# branch_counts = {
#    ' Placement': np.array([27, 33, 32]),
#     'Higher studies': np.array([2, 2, 0]),
#     "Entrepreneurs":np.array([0, 0, 0])

# }
# width=0.25
# c=["red","green","blue","black"]
# plt.xlabel("Year")
# plt.ylabel("No. of students")
# plt.title("Improvement in Placement, Higher Studies and Entrepreneurship")


# set width of bar
barWidth = 0.25
# fig = plt.subplots(figsize =(12, 8))
# fig = plt.subplots()
# set height of bar
Placement = [27, 33, 32]
Higher_studies = [2, 2, 5]
Entrepreneurs = [1, 0, 3]

# Set position of bar on X axis
br1 = np.arange(len(Placement))
br2 = [x + barWidth for x in br1]
br3 = [x + barWidth for x in br2]

# Make the plot
plt.bar(br1, Placement, color ='b', width = barWidth,
        edgecolor ='grey', label ='Placement')
plt.bar(br2, Higher_studies , color ='g', width = barWidth,
        edgecolor ='grey', label ='Higher studies')
plt.bar(br3, Entrepreneurs, color ='r', width = barWidth,
        edgecolor ='grey', label ='Entrepreneurs')

# Adding Xticks
plt.xlabel('Year', fontweight ='bold', fontsize = 15)
plt.ylabel('No. of students', fontweight ='bold', fontsize = 15)
# plt.xticks([r + barWidth for r in range(len(Placement))], ['2017-21', '2018-22', '2019-23'])
plt.xticks([r + barWidth for r in range(len(Placement))], ['2017-21', '2018-22', '2019-23'])
# plt.legend(loc='upper left', ncols=3)
plt.title("Improvement in Placement, Higher Studies and Entrepreneurship")
plt.legend()
plt.savefig("cr_7_2")

# %%
import matplotlib.pyplot as plt
import numpy as np
species = ("Adelie", "Chinstrap", "Gentoo")
penguin_means = {
    'Bill Depth': (18.35, 18.43, 14.98),
    'Bill Length': (38.79, 48.83, 47.50),
    'Flipper Length': (189.95, 195.82, 217.19),
}
x = np.arange(len(species))  # the label locations
width = 0.25  # the width of the bars
multiplier = 0
fig, ax = plt.subplots(layout='constrained')
for attribute, measurement in penguin_means.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute)
    ax.bar_label(rects, padding=2)
    multiplier += 1
# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Length (mm)')
ax.set_title('Penguin attributes by species')
ax.set_xticks(x + width, species)
ax.legend(loc='upper left', ncols=3)
ax.set_ylim(0, 250)
plt.show()
